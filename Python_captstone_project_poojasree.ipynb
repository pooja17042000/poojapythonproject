# %% [markdown]
# # Task 1

# %%
import pandas as pd
data=pd.read_csv("DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")
data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
data.shape
# Out:
# (4803, 20)

# %% [markdown]
# There are 4803 rows and 20 columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
first_50movies=data.loc[:,['original_title','genres']].head(50)
first_50movies
# Out:
#                                  original_title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# # Task 2(null values finding and treatment)

# %%
data.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
from tabulate import tabulate
list_1=data.select_dtypes(include='object')
list_2=data.select_dtypes(exclude='object')
print(tabulate({"Categorical":list_1,
                "continuous": list_2}, headers = ["categorical", "continuous"]))
# Out:
# categorical           continuous
# --------------------  ------------
# genres                budget
# homepage              id
# keywords              popularity
# original_language     revenue
# original_title        runtime
# overview              vote_average
# production_companies  vote_count
# production_countries
# release_date
# spoken_languages
# status
# tagline
# title

# %% [markdown]
# # There are two columns has null values they are homepage and title,overview,release date,runtime

# %% [markdown]
# # title,homepage and release data,over view are categorical columns and runtime is continuous

# %%
#for categorical columns the treatment is findout frequent value in column and use fill na to fill with frequent value
data.title.value_counts()
# Out:
# The Host                 2
# Batman                   2
# Out of the Blue          2
# Avatar                   1
# The Girl on the Train    1
#                         ..
# Step Up 3D               1
# Secondhand Lions         1
# The Age of Adaline       1
# Drag Me to Hell          1
# My Date with Drew        1
# Name: title, Length: 4800, dtype: int64

# %%
#filling with host title
data.title=data.title.fillna('The Host')

# %%
data.homepage.value_counts()
# Out:
# http://www.missionimpossible.com/                       4
# http://www.thehungergames.movie/                        4
# http://www.kungfupanda.com/                             3
# http://www.transformersmovie.com/                       3
# http://www.thehobbit.com/                               3
#                                                        ..
# http://www.ridealong.com/                               1
# http://www.theinternmovie.com/                          1
# http://www.miramax.com/movie/the-talented-mr-ripley/    1
# http://www.julieandjulia.com/                           1
# http://shanghaicalling.com/                             1
# Name: homepage, Length: 1691, dtype: int64

# %%
data.homepage=data.homepage.fillna('http://www.missionimpossible.com/')

# %%
data.release_date.value_counts()
# Out:
# 01-01-2006    10
# 01-01-2002     8
# 03-09-2004     7
# 22-10-1999     7
# 18-07-2013     7
#               ..
# 30-12-2002     1
# 20-08-2002     1
# 05-11-1987     1
# 11-11-2004     1
# 03-05-2012     1
# Name: release_date, Length: 3280, dtype: int64

# %%
data.release_date=data.release_date.fillna('01-01-2006')

# %%
data.overview.value_counts()
# Out:
# In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.                                                                                                                                                                                                                                                                                            1
# While undergoing heart surgery, a man experiences a phenomenon called ‘anesthetic awareness’, which leaves him awake but paralyzed throughout the operation. As various obstacles present themselves, his wife must make life-altering decisions while wrestling with her own personal drama.                                                                                                                                                                              1
# ...

# %%
data.tagline.value_counts()
# Out:
# Based on a true story.                          3
# From zero to hero.                              2
# The only way out is down.                       2
# Be careful what you wish for.                   2
# What could go wrong?                            2
#                                                ..
# Life is Not Child-Proof.                        1
# Every war has a beginning.                      1
# First came love... then came Reverend Frank.    1
# Get off the bench and get into the game.        1
# A New Yorker in Shanghai                        1
# Name: tagline, Length: 3944, dtype: int64

# %%
data.tagline=data.tagline.fillna('Based on a true story.')

# %%
data.overview=data.overview.fillna('In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.')

# %%
#for filling numerical columns they filled with mean using fillna
data.runtime=data.runtime.fillna(data.runtime.mean())

# %%
#checking null values after filling
data.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# # Null values are treated and there no missing data in dataset

# %% [markdown]
# # Task 3 (movie categories that have budget greater than 2,20,000 )

# %%
genres_budget=data.loc[:,['genres','budget']]
genres_budget
# Out:
#                                                  genres     budget
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  237000000
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...  300000000
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  245000000
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...  250000000
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  260000000
# ...                                                 ...        ...
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...     220000
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...       9000
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...          0
# 4801                                                 []          0
# 4802                [{"id": 99, "name": "Documentary"}]          0
#
# [4803 rows x 2 columns]

# %%
genres_budget=genres_budget[genres_budget['budget']>220000]
genres_budget
# Out:
#                                                  genres     budget
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  237000000
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...  300000000
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  245000000
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...  250000000
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  260000000
# ...                                                 ...        ...
# 4680  [{"id": 80, "name": "Crime"}, {"id": 27, "name...     450000
# 4682                     [{"id": 27, "name": "Horror"}]   13000000
# 4720                      [{"id": 18, "name": "Drama"}]    8500000
# 4758  [{"id": 53, "name": "Thriller"}, {"id": 878, "...    4000000
# 4770  [{"id": 18, "name": "Drama"}, {"id": 35, "name...     500000
#
# [3684 rows x 2 columns]

# %% [markdown]
# # There are movies greater than 2,20,000 budget are 3684 movies out of 4803 movies

# %% [markdown]
# # Task 4(movie categories revenue greater than 961,000,000)

# %%
genre_revenue=data.loc[:,['genres','revenue']]
genre_revenue=genre_revenue[genre_revenue['revenue']>961000000]
genre_revenue
# Out:
#                                                 genres     revenue
# 0    [{"id": 28, "name": "Action"}, {"id": 12, "nam...  2787965087
# 3    [{"id": 28, "name": "Action"}, {"id": 80, "nam...  1084939099
# 7    [{"id": 28, "name": "Action"}, {"id": 12, "nam...  1405403694
# 12   [{"id": 12, "name": "Adventure"}, {"id": 14, "...  1065659812
# 16   [{"id": 878, "name": "Science Fiction"}, {"id"...  1519557910
# 17   [{"id": 12, "name": "Adventure"}, {"id": 28, "...  1045713802
# 25   [{"id": 18, "name": "Drama"}, {"id": 10749, "n...  1845034188
# 26   [{"id": 12, "name": "Adventure"}, {"id": 28, "...  1153304495
# 28   [{"id": 28, "name": "Action"}, {"id": 12, "nam...  1513528810
# 29   [{"id": 28, "name": "Action"}, {"id": 12, "nam...  1108561013
# 31   [{"id": 28, "name": "Action"}, {"id": 12, "nam...  1215439994
# 32   [{"id": 10751, "name": "Family"}, {"id": 14, "...  1025491110
# 36   [{"id": 878, "name": "Science Fiction"}, {"id"...  1091405097
# ...

# %% [markdown]
# # There are 24 movies which have revenue greater than 960 million

# %% [markdown]
# # Task 5 (remove 0 value in the revenue and budget columns)

# %%
data1 = data[data['budget'] == 0 ].index

# %%
data.drop(data1,inplace=True)

# %%
data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4791         13                     [{"id": 27, "name": "Horror"}]
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # After removing rows with 0 values in budget there are 3766 rows.

# %%
#removing the revenue with 0 values
data2 = data[data['revenue'] == 0 ].index

# %%
data.drop(data2,inplace=True)

# %%
data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # Therefore the 0 values in the revenue and budget are dropped and there are 3229 rows out of 4803 rows

# %% [markdown]
# # Task 6(top 10 movies with highest revenue and top 10 movies with least budget)

# %%
top10_highestrevenue=data.loc[:,['title','revenue']].sort_values(by=['revenue'],ascending=False).head(10)
top10_highestrevenue
# Out:
#                           title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 124                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 546                     Minions  1156730962
# 26   Captain America: Civil War  1153304495

# %%
top10_lowbudget=data.loc[:,['title','budget']].sort_values(by=['budget']).head(10)
top10_lowbudget
# Out:
#                    title  budget
# 4238        Modern Times       1
# 3611  A Farewell to Arms       4
# 3372        Split Second       7
# 3419        Bran Nue Dae       7
# 4608        The Prophecy       8
# 3131   Of Horses and Men      10
# 3137           Nurse 3-D      10
# 2933            F.I.S.T.      11
# 1912      Angela's Ashes      25
# 1771      The 51st State      28

# %% [markdown]
# # Task 7(movie popularity based on budget are they correlated and uncorrelated)

# %%
import matplotlib.pyplot as plt

# %%
#heatmap
fig,ax=plt.subplots(figsize=(20,10))
sns.heatmap(data.corr(),annot=True ,cbar=3,linewidth=5)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6424\466431093.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True ,cbar=3,linewidth=5)

# %%
a=data.loc[:,['popularity','budget']].head(10)
a
# Out:
#    popularity     budget
# 0  150.437577  237000000
# 1  139.082615  300000000
# 2  107.376788  245000000
# 3  112.312950  250000000
# 4   43.926995  260000000
# 5  115.699814  258000000
# 6   48.681969  260000000
# 7  134.279229  280000000
# 8   98.885637  250000000
# 9  155.790452  250000000

# %%
correlation_BTW_budget_popularity=data['budget'].corr(data['popularity'])
correlation_BTW_budget_popularity
# Out:
# 0.43199013600797564

# %% [markdown]
# # So is budget a better indicator of movie popularity, as measured by box office take? a film’s lifetime_gross correlates more strongly to vote_average than budget. Better films make more money!
# # And budget and revenue also strong correlated with 0.7 correlation hence if budget is more if it is a good film and it has high chances of revenue and gains popularity.

# %% [markdown]
# # Task 8

# %%
d=data.loc[:,['production_companies']]
d
# Out:
#                                    production_companies
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 4773  [{"name": "Miramax Films", "id": 14}, {"name":...
# 4788     [{"name": "Dreamland Productions", "id": 407}]
# 4792             [{"name": "Daiei Studios", "id": 881}]
# 4796                 [{"name": "Thinkfilm", "id": 446}]
# 4798           [{"name": "Columbia Pictures", "id": 5}]
#
# [3229 rows x 1 columns]

# %%
data3 = data[data['production_companies'] =='[]'].index

# %%
data.drop(data3,inplace=True)

# %%
count_production_companies=data.loc[:,['title','production_companies']].groupby(['production_companies']).count()
count_production_companies
# Out:
#                                                     title
# production_companies
# [{"name": "100 Bares", "id": 5517}, {"name": "H...      1
# [{"name": "100 Bares", "id": 5517}, {"name": "M...      1
# [{"name": "1492 Pictures", "id": 436}, {"name":...      1
# [{"name": "1492 Pictures", "id": 436}, {"name":...      2
# [{"name": "1492 Pictures", "id": 436}, {"name":...      1
# ...                                                   ...
# [{"name": "Zentropa Entertainments", "id": 76},...      1
# [{"name": "Zentropa Entertainments", "id": 76},...      1
# [{"name": "Zininsa Film Production", "id": 7653...      1
# [{"name": "area japan", "id": 6536}]                    1
# [{"name": "icon", "id": 4096}]                          1
#
# [2632 rows x 1 columns]

# %%
s=count_production_companies.sort_values(['title'],ascending=False).groupby('production_companies').head(10)
s
# Out:
#                                                     title
# production_companies
# [{"name": "Paramount Pictures", "id": 4}]              48
# [{"name": "Universal Pictures", "id": 33}]             35
# [{"name": "New Line Cinema", "id": 12}]                29
# [{"name": "Columbia Pictures", "id": 5}]               28
# [{"name": "Twentieth Century Fox Film Corporati...     25
# ...                                                   ...
# [{"name": "Ingenious Film Partners", "id": 289}...      1
# [{"name": "Ingenious Film Partners", "id": 289}...      1
# [{"name": "Ingenious Film Partners", "id": 289}...      1
# [{"name": "Ingenious Film Partners", "id": 289}...      1
# [{"name": "icon", "id": 4096}]                          1
#
# [2632 rows x 1 columns]

# %%
s = s.rename({"title":"count of production companies"}, axis='columns')
s
# Out:
#                                                     count of production companies
# production_companies
# [{"name": "Paramount Pictures", "id": 4}]                                      48
# [{"name": "Universal Pictures", "id": 33}]                                     35
# [{"name": "New Line Cinema", "id": 12}]                                        29
# [{"name": "Columbia Pictures", "id": 5}]                                       28
# [{"name": "Twentieth Century Fox Film Corporati...                             25
# ...                                                                           ...
# [{"name": "Ingenious Film Partners", "id": 289}...                              1
# [{"name": "Ingenious Film Partners", "id": 289}...                              1
# [{"name": "Ingenious Film Partners", "id": 289}...                              1
# [{"name": "Ingenious Film Partners", "id": 289}...                              1
# ...

# %% [markdown]
# # The production company paramount has more movies produced 48 movies

# %% [markdown]
# # Task 9

# %%
count_production_companies=data.loc[:,['title','production_companies']].groupby(['production_companies']).count().sort_values(by='title',ascending=False).head(25)
count_production_companies
# Out:
#                                                     title
# production_companies
# [{"name": "Paramount Pictures", "id": 4}]              48
# [{"name": "Universal Pictures", "id": 33}]             35
# [{"name": "New Line Cinema", "id": 12}]                29
# [{"name": "Columbia Pictures", "id": 5}]               28
# [{"name": "Twentieth Century Fox Film Corporati...     25
# [{"name": "Metro-Goldwyn-Mayer (MGM)", "id": 84...     24
# [{"name": "Warner Bros.", "id": 6194}]                 24
# [{"name": "Walt Disney Pictures", "id": 2}]            18
# [{"name": "Touchstone Pictures", "id": 9195}]          15
# [{"name": "Dimension Films", "id": 7405}]              13
# [{"name": "Columbia Pictures Corporation", "id"...     13
# [{"name": "DreamWorks Animation", "id": 521}]          12
# [{"name": "Walt Disney Pictures", "id": 2}, {"n...     11
# [{"name": "United Artists", "id": 60}]                 10
# [{"name": "Miramax Films", "id": 14}]                   9
# ...

# %% [markdown]
# # The top 25 production house is paramount pictures and produced only 5 which is least in t0p 25 is walt Disney productions.

# %% [markdown]
# # Task 10

# %%
top500_movies_revenue=data.sort_values(by='revenue',ascending=False).head(500)
top500_movies_revenue=top500_movies_revenue.loc[:,['revenue','budget','runtime','title']]
top500_movies_revenue
# Out:
#          revenue     budget  runtime                title
# 0     2787965087  237000000    162.0               Avatar
# 25    1845034188  200000000    194.0              Titanic
# 16    1519557910  220000000    143.0         The Avengers
# 28    1513528810  150000000    124.0       Jurassic World
# 44    1506249360  190000000    137.0            Furious 7
# ...          ...        ...      ...                  ...
# 397    219103655   85000000    121.0     It's Complicated
# 1744   219076518   30000000    129.0           Knocked Up
# 698    218613188   70000000     99.0  The Prince of Egypt
# 717    218340595   60000000    130.0         Jack Reacher
# 714    217764291   65000000    120.0           Collateral
#
# [500 rows x 4 columns]

# %%
import seaborn as sns
import statistics as st

# %%
Mean=[]
Median=[]
Mode=[]
for col in top500_movies_revenue.head():
    Mean.append(top500_movies_revenue.loc[:,col].mean()) #calculating each column mean and stored within Mean named list
    Median.append(top500_movies_revenue.loc[:,col].median()) #calculating each column median and stored within Median named list
    Mode.append(st.mode(top500_movies_revenue[col])) #calculating each column mode and stored within Mode named list
    
row_head=['Mean','Median','Mode']
col_names=['revenue','budget','runtime']

#Creating a new dataframe with all calculated mean, median, and mode of 3 companies
d_data=pd.DataFrame([Mean, Median, Mode],columns=col_names)

#Inserting a new column 'Measures' at the begining of the dataframe with 3 measures names
d_data.insert(0, "Measures", row_head, True)

print(d_data)
# Out:
#   Measures       revenue       budget  runtime
# 0     Mean  4.585776e+08  103193736.0   118.72
# 1   Median  3.630016e+08   95000000.0   116.00
# 2     Mode  2.787965e+09  150000000.0   115.00

# %%
for column in top500_movies_revenue:
    plt.figure()
    top500_movies_revenue.boxplot([column])

# %% [markdown]
# # Revenue has more outliers and budget has only two outliers and budget data spread is more

# %% [markdown]
# # Task 11(movies having more than average runtime)

# %%
avg_runtime=top500_movies_revenue[top500_movies_revenue['runtime']>118.72]
avg_runtime.loc[:,['title','runtime']]
# Out:
#                  title  runtime
# 0               Avatar    162.0
# 25             Titanic    194.0
# 16        The Avengers    143.0
# 28      Jurassic World    124.0
# 44           Furious 7    137.0
# ...                ...      ...
# 521       The Terminal    128.0
# 397   It's Complicated    121.0
# 1744        Knocked Up    129.0
# 717       Jack Reacher    130.0
# 714         Collateral    120.0
#
# [234 rows x 2 columns]

# %% [markdown]
# # Top 10 runtime movies in list top 500 most revenue films

# %%
avg_runtime.loc[:,['title','runtime']].sort_values(by='runtime',ascending=False).head(10)
# Out:
#                                               title  runtime
# 3813                             Gone with the Wind    238.0
# 329   The Lord of the Rings: The Return of the King    201.0
# 1818                               Schindler's List    195.0
# 25                                          Titanic    194.0
# 690                                  The Green Mile    189.0
# 24                                        King Kong    187.0
# 110                                    Pearl Harbor    183.0
# 2278                             Dances with Wolves    181.0
# 298                         The Wolf of Wall Street    180.0
# 330           The Lord of the Rings: The Two Towers    179.0

# %% [markdown]
# # The film Gone with the wind has most runtime of 238 minutes
